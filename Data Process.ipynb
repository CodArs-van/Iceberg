# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
random.seed(1)

# %%
cg = dict()
cg['path'] = '/home/iceberg'

# %%
def discover_train(config):
    df = pd.read_json(os.path.join(config['path'], 'train.json'))
    return df

df_train = discover_train(cg)
df_train
# Out:
#                                                  band_1  \
# 0     [-27.878360999999998, -27.15416, -28.668615, -...
# 1     [-12.242375, -14.920304999999999, -14.920363, ...
# 2     [-24.603676, -24.603714, -24.871029, -23.15277...
# 3     [-22.454607, -23.082819, -23.998013, -23.99805...
# 4     [-26.006956, -23.164886, -23.164886, -26.89116...
# 5     [-20.769371, -20.769434, -25.906025, -25.90602...
# 6     [-26.673811, -23.666162, -27.622442, -28.31768...
# 7     [-24.989119, -27.755224, -25.817074, -24.98927...
# 8     [-17.146641, -17.146572, -17.994583, -19.44553...
# 9     [-24.020853, -23.551275, -27.18819, -29.126434...
# 10    [-21.397552, -19.753859, -23.426783, -24.65221...
# 11    [-22.020813, -22.020864, -20.345379, -18.07829...
# 12    [-21.112206, -21.638832, -25.436468, -23.22255...
# 13    [-23.864258, -27.755791, -26.047226, -24.62014...
# 14    [-20.558899, -21.328135, -19.585205, -19.71788...
# 15    [-28.282215, -27.896156, -25.882795, -25.88279...
# ...

# %% [markdown]
# ## Summary
#
# * 1604 Rows
# * Many na's

# %% [markdown]
# Show some of the pictures

# %%
df_sampled = df_train.sample(n=8)
df_sampled
for i, (band1, band2, id_num, inc_angle, iceberg) in enumerate(df_sampled.values):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

def plotimages(df, n):
    df_sampled = df.sample(n=n)
    
    fig = plt.figure(1, figsize=(24,24))
    grid = ImageGrid(fig, 111,  # similar to subplot(111)
                     nrows_ncols=(n, 4),  # creates nx2 grid of axes
                     axes_pad=0.1)  # pad between axes in inch.
    
    for i, (band1, band2, id_num, inc_angle, iceberg) in enumerate(df_sampled.values):
        ax = grid[(i*2)]
        band1_sample = band1
        band1_sample = np.array(band1_sample).reshape(75, 75)
        ax.imshow(band1_sample / 75.)
        ax.text(10, 4, 'Id: %s %s' % (id_num, "Band_1"), color='k', backgroundcolor='m', alpha=0.8)
        ax.text(10, 10, 'Incidence Angle: (%s)' % str(inc_angle), color='w', backgroundcolor='k', alpha=0.8)
        ax.text(10, 16, 'Is Iceberg: %s' % iceberg, color='k', backgroundcolor='w', alpha=0.8)
        ax.axis('on')
        # plot band 2
        ax = grid[(i*2)+1]
        band2_sample = band2
        band2_sample = np.array(band2_sample).reshape(75, 75)
        ax.imshow(band2_sample / 75.)
        ax.text(10, 4, 'Id: %s %s' % (id_num, "Band_2"), color='k', backgroundcolor='m', alpha=0.8)
        ax.axis('on')
        
    plt.show()

# %%
plotimages(df_train, 4)
